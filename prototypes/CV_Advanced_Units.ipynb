# %% [markdown]
# <P> From the advanced units, data augmentation appeared the most relevant for developing better models.
# <P> Given FCN and deep CNN (of which UNet and U2Net are based on) are able to discen features from different parts of the image, we apply noise and change the image brightness to best match real world use cases.
#     <P> For instance, not all cameras are able to take high quality photos and not all photos are taken in well lit environments.

# %%
import numpy as np
import cv2
import argparse
import matplotlib.pyplot as plt

# %%
# import image from training

image = cv2.imread("/Users/narekgeghamyan/local_data/capstone_data/imaterialist-fashion-2019-FGVC6/test/0a72e0f76ab9b75945f5d610508f9336.jpg", cv2.COLOR_RGB2BGR)

# %%
plt.imshow(image)

# %%
new_image = np.zeros(image.shape, image.dtype)

# %%
alpha = 1.0 # Simple contrast control (1.0 - 3.0)
beta = 70    # Simple brightness control (0 - 100)
new_image = cv2.convertScaleAbs(image, alpha=alpha, beta=beta)

# %%
plt.imshow(new_image)
